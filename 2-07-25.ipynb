# %%
import networkx as nx
import triad_utils
import numpy as np
import scipy.sparse as sp
import matplotlib.pyplot as plt
import random as rn
import sprofiles_utils

# %%
censuses, sps = sprofiles_utils.create_profile("comm-f2f-Resistance/network/network59.csv", 1, "network59")
# Out:
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# ...
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# s.p. successfully appended
# file successfully created
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 censuses, sps = sprofiles_utils.create_profile("comm-f2f-Resistance/network/network59.csv", 1, "network59")
#
# ValueError: too many values to unpack (expected 2)

# %%
#creates plot of significance value for the triad as a function of time t
def create_time_plot(sp, sp_number, censuses):
    x = list(range(0,6729,100))
    #for i in range(0, 13):
        #for j in range(0, len(censuses):
    y = sp
    plt.plot(x,y, label=f"triad {sp_number+1}")

# %%
plt.figure(figsize=(18, 6))
#triads 2,3,4, and 8 were the ones that changed from 0
for t in range(0,13):
    create_time_plot([sp[t] for sp in sps], t, censuses)


plt.legend()
plt.xlabel("Time (1/3 s)")
plt.ylabel("Significance")
plt.axhline(y=0, color='black', linestyle='--', linewidth=1)
plt.title("Triad Significance Over Time")
